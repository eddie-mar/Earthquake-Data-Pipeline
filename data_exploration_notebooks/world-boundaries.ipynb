# %% [markdown]
# In this notebook, we are gonna add country and region data for our raw dataset

# %%
import pandas as pd
import geopandas as gpd
import pyspark
import re

from shapely.geometry import Point
from pyspark.sql import SparkSession
from tqdm import tqdm

# %%
df = pd.read_csv('earthquake-data.csv')
# Out:
# /tmp/ipykernel_8784/2639961088.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('earthquake-data.csv')

# %%
df.shape
# Out:
# (4608354, 10)

# %%
df = df.head(10000)

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.sample(10)
# Out:
#                                    place          time  magnitude        lat  \
# 54               Kermadec Islands region -632483599770        NaN -27.349000
# 5417             21km ESE of Olancha, CA -841320100590       3.19  36.234667
# 6083  240 km WNW of Port McNeill, Canada -876916830440       6.24  51.384000
# 5843         4 km NW of Cedar City, Utah -862707120000        NaN  37.700000
# 3303      129 km ENE of Mawlaik, Myanmar -735381755760       7.07  24.104000
# 8579             73 km E of Iwaki, Japan -999940493570       5.76  36.982000
# 4277               32km SE of Avalon, CA -778377795050       3.36  33.153000
# 805                       south of Tonga -654048698830        NaN -25.083000
# 6566        27km ENE of Independence, CA -901489320130       3.27  36.861833
# 1860          10 km SE of Naama, Algeria -688060433980       5.41  33.194000
#
#             long  depth alert  tsunami  tz        type
# 54   -177.154000   35.0   NaN        0 NaN  earthquake
# 5417 -117.776833    6.0   NaN        0 NaN  earthquake
# 6083 -130.267000   15.0   NaN        0 NaN  earthquake
# 5843 -113.100000    NaN   NaN        0 NaN  earthquake
# 3303   95.575000   15.0   NaN        0 NaN  earthquake
# 8579  141.707000   25.0   NaN        0 NaN  earthquake
# 4277 -118.062000    6.0   NaN        0 NaN  earthquake
# 805  -175.391000   15.0   NaN        0 NaN  earthquake
# 6566 -117.906833    6.0   NaN        0 NaN  earthquake
# 1860   -0.253000   15.0   NaN        0 NaN  earthquake

# %% [markdown]
# We will get our countries data in ne_10m_admin_0_countries.shp file

# %%
geometry = [Point(xy) for xy in zip(df['long'], df['lat'])]
gdf_points = gpd.GeoDataFrame(df, geometry=geometry, crs='EPSG:4326')

world = gpd.read_file('world-boundaries/ne_10m_admin_0_countries.shp') 

gdf_with_country = gpd.sjoin(gdf_points, world[['geometry', 'ADMIN', 'REGION_UN']].rename(columns={
    'ADMIN': 'country',
    'REGION_UN': 'region'
}), how='left', predicate='within')

# %%
gdf_with_country.sample(10)
# Out:
#                                      place           time  magnitude  \
# 1818         2 km NNE of Kingsbury, Nevada  -686727220000       4.60
# 9535          34km W of San Miguel Is., CA -1044497303300       2.89
# 7668              63 km NNW of Kuqa, China  -962222878450       5.58
# 5643             115 km W of Hihifo, Tonga  -852925516220       6.30
# 3623              18km WNW of Inyokern, CA  -746739288000       2.80
# 4054        171 km W of Abepura, Indonesia  -764866039720        NaN
# 3239         126 km S of Ierápetra, Greece  -732681321080       5.67
# 3972  86 km NNW of Alianza Cristiana, Peru  -758874789430        NaN
# 7514            9km E of Big Bear City, CA  -952740784070       2.29
# 8890            4km WNW of Mead Valley, CA -1015713782300       2.43
#
#             lat        long  depth alert  tsunami  tz        type  \
# 1818  39.000000 -119.900000    NaN   NaN        0 NaN  earthquake
# 9535  34.066833 -120.735000    6.0   NaN        0 NaN  earthquake
# 7668  42.208000   82.530000   15.0   NaN        0 NaN  earthquake
# 5643 -15.854000 -174.874000   15.0   NaN        0 NaN  earthquake
# 3623  35.700000 -118.000000    6.0   NaN        0 NaN  earthquake
# 4054  -2.338000  139.110000   35.0   NaN        0 NaN  earthquake
# 3239  33.898000   26.011000   15.0   NaN        0 NaN  earthquake
# 3972  -2.750000  -76.734000  117.8   NaN        0 NaN  earthquake
# 7514  34.255500 -116.746833    6.0   NaN        0 NaN  earthquake
# 8890  33.842167 -117.335167    6.0   NaN        0 NaN  earthquake
#
#                          geometry  index_right                   country  \
# 1818            POINT (-119.9 39)        154.0  United States of America
# 9535    POINT (-120.735 34.06683)          NaN                       NaN
# 7668         POINT (82.53 42.208)          9.0                     China
# 5643     POINT (-174.874 -15.854)          NaN                       NaN
# 3623            POINT (-118 35.7)        154.0  United States of America
# 4054        POINT (139.11 -2.338)          0.0                 Indonesia
# 3239        POINT (26.011 33.898)          NaN                       NaN
# 3972        POINT (-76.734 -2.75)          4.0                      Peru
# 7514   POINT (-116.74683 34.2555)        154.0  United States of America
# 8890  POINT (-117.33517 33.84217)        154.0  United States of America
#
#         region
# 1818  Americas
# 9535       NaN
# 7668      Asia
# 5643       NaN
# 3623  Americas
# 4054      Asia
# 3239       NaN
# 3972  Americas
# 7514  Americas
# 8890  Americas

# %%
gdf_with_country.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   place        10000 non-null  object
#  1   time         10000 non-null  int64
#  2   magnitude    7635 non-null   float64
#  3   lat          10000 non-null  float64
#  4   long         10000 non-null  float64
#  5   depth        9837 non-null   float64
#  6   alert        0 non-null      object
#  7   tsunami      10000 non-null  int64
#  8   tz           0 non-null      float64
#  9   type         10000 non-null  object
#  10  geometry     10000 non-null  geometry
#  11  index_right  6178 non-null   float64
#  12  country      6178 non-null   object
#  13  region       6178 non-null   object
# dtypes: float64(6), geometry(1), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
study_df = gdf_with_country[gdf_with_country.country.isnull()]

# %%
study_df
# Out:
#                                             place           time  magnitude  \
# 5                       south of the Fiji Islands  -631286334600        NaN
# 7                   91 km NNE of Lasem, Indonesia  -631331600890        NaN
# 8                         Kermadec Islands region  -631351025130        NaN
# 14                      33 km SSE of Adak, Alaska  -631448307640        NaN
# 15             east of the South Sandwich Islands  -631460084000        NaN
# ...                                           ...            ...        ...
# 9990  139 km NNW of Finschhafen, Papua New Guinea -1059060996230        NaN
# 9992            144 km WNW of Pariaman, Indonesia -1059117808160       6.03
# 9993                                Greenland Sea -1059333702770       5.68
# 9994                                Norwegian Sea -1059336071260       5.44
# 9997                  northern Mid-Atlantic Ridge -1059377901680       5.65
#
#          lat     long  depth alert  tsunami  tz        type  \
# 5    -26.927 -176.566   15.0   NaN        0 NaN  earthquake
# 7     -5.923  111.759  605.0   NaN        0 NaN  earthquake
# 8    -27.889 -177.108  135.0   NaN        0 NaN  earthquake
# 14    51.584 -176.509   35.0   NaN        0 NaN  earthquake
# 15   -59.169  -20.328   15.0   NaN        0 NaN  earthquake
# ...      ...      ...    ...   ...      ...  ..         ...
# 9990  -5.443  147.253  150.0   NaN        0 NaN  earthquake
# 9992  -0.172   98.898   35.0   NaN        0 NaN  earthquake
# 9993  73.128    6.098   15.0   NaN        0 NaN  earthquake
# 9994  72.678    1.764   15.0   NaN        0 NaN  earthquake
# 9997  26.923  -43.335   15.0   NaN        0 NaN  earthquake
#
#                       geometry  index_right country region
# 5     POINT (-176.566 -26.927)          NaN     NaN    NaN
# 7       POINT (111.759 -5.923)          NaN     NaN    NaN
# 8     POINT (-177.108 -27.889)          NaN     NaN    NaN
# 14     POINT (-176.509 51.584)          NaN     NaN    NaN
# 15     POINT (-20.328 -59.169)          NaN     NaN    NaN
# ...                        ...          ...     ...    ...
# 9990    POINT (147.253 -5.443)          NaN     NaN    NaN
# 9992     POINT (98.898 -0.172)          NaN     NaN    NaN
# 9993      POINT (6.098 73.128)          NaN     NaN    NaN
# 9994      POINT (1.764 72.678)          NaN     NaN    NaN
# 9997    POINT (-43.335 26.923)          NaN     NaN    NaN
#
# [3822 rows x 14 columns]

# %%
study_df.isnull().sum()
# Out:
# place             0
# time              0
# magnitude      1501
# lat               0
# long              0
# depth            41
# alert          3822
# tsunami           0
# tz             3822
# type              0
# geometry          0
# index_right    3822
# country        3822
# region         3822
# dtype: int64

# %% [markdown]
# As we can see, there are still null country values even though there is no null latitude and longitude. From a small search, this is due to unclaimed territories or discrepancy in our reference file. We can also see that we can fill some as the country is written in their place column.

# %% [markdown]
# Generated country and region column in gdf_with_country dataframe. But a lot of null countries. Let us try to fill some up.

# %%
world[['ADMIN', 'REGION_UN']]
# Out:
#                             ADMIN REGION_UN
# 0                       Indonesia      Asia
# 1                        Malaysia      Asia
# 2                           Chile  Americas
# 3                         Bolivia  Americas
# 4                            Peru  Americas
# ..                            ...       ...
# 253                   Macao S.A.R      Asia
# 254   Ashmore and Cartier Islands   Oceania
# 255  Bajo Nuevo Bank (Petrel Is.)  Americas
# 256               Serranilla Bank  Americas
# 257              Scarborough Reef      Asia
#
# [258 rows x 2 columns]

# %%
world_data = world[['ADMIN', 'REGION_UN']].to_json()
print(type(world_data))
print(world_data)
# Out:
# <class 'str'>
# {"ADMIN":{"0":"Indonesia","1":"Malaysia","2":"Chile","3":"Bolivia","4":"Peru","5":"Argentina","6":"Dhekelia Sovereign Base Area","7":"Cyprus","8":"India","9":"China","10":"Israel","11":"Palestine","12":"Lebanon","13":"Ethiopia","14":"South Sudan","15":"Somalia","16":"Kenya","17":"Malawi","18":"United Republic of Tanzania","19":"Syria","20":"Somaliland","21":"France","22":"Suriname","23":"Guyana","24":"South Korea","25":"North Korea","26":"Morocco","27":"Western Sahara","28":"Costa Rica","29":"Nicaragua","30":"Republic of the Congo","31":"Democratic Republic of the Congo","32":"Bhutan","33":"Ukraine","34":"Belarus","35":"Namibia","36":"South Africa","37":"Saint Martin","38":"Sint Maarten","39":"Oman","40":"Uzbekistan","41":"Kazakhstan","42":"Tajikistan","43":"Lithuania","44":"Brazil","45":"Uruguay","46":"Mongolia","47":"Russia","48":"Czechia","49":"Germany","50":"Estonia","51":"Latvia","52":"Norway","53":"Sweden","54":"Finland","55":"Vietnam","56":"Cambodia","57":"Luxembourg","58":"United Arab Emirates","59":"Belgium","60":"Georgia","61":"North Macedonia","62":"Albania","63":"Azerbaijan","64":"Kosovo","65":"Turkey","66":"Spain","67":"Laos","68":"Kyrgyzstan","69":"Armenia","70":"Denmark","71":"Libya","72":"Tunisia","73":"Romania","74":"Hungary","75":"Slovakia","76":"Poland","77":"Ireland","78":"United Kingdom","79":"Greece","80":"Zambia","81":"Sierra Leone","82":"Guinea","83":"Liberia","84":"Central African Republic","85":"Sudan","86":"Djibouti","87":"Eritrea","88":"Austria","89":"Iraq","90":"Italy","91":"Switzerland","92":"Iran","93":"Netherlands","94":"Liechtenstein","95":"Ivory Coast","96":"Republic of Serbia","97":"Mali","98":"Senegal","99":"Nigeria","100":"Benin","101":"Angola","102":"Croatia","103":"Slovenia","104":"Qatar","105":"Saudi Arabia","106":"Botswana","107":"Zimbabwe","108":"Pakistan","109":"Bulgaria","110":"Thailand","111":"San Marino","112":"Haiti","113":"Dominican Republic","114":"Chad","115":"Kuwait","116":"El Salvador","117":"Guatemala","118":"East Timor","119":"Brunei","120":"Monaco","121":"Algeria","122":"Mozambique","123":"eSwatini","124":"Burundi","125":"Rwanda","126":"Myanmar","127":"Bangladesh","128":"Andorra","129":"Afghanistan","130":"Montenegro","131":"Bosnia and Herzegovina","132":"Uganda","133":"US Naval Base Guantanamo Bay","134":"Cuba","135":"Honduras","136":"Ecuador","137":"Colombia","138":"Paraguay","139":"Brazilian Island","140":"Portugal","141":"Moldova","142":"Turkmenistan","143":"Jordan","144":"Nepal","145":"Lesotho","146":"Cameroon","147":"Gabon","148":"Niger","149":"Burkina Faso","150":"Togo","151":"Ghana","152":"Guinea-Bissau","153":"Gibraltar","154":"United States of America","155":"Canada","156":"Mexico","157":"Belize","158":"Panama","159":"Venezuela","160":"Papua New Guinea","161":"Egypt","162":"Yemen","163":"Mauritania","164":"Equatorial Guinea","165":"Gambia","166":"Hong Kong S.A.R.","167":"Vatican","168":"Northern Cyprus","169":"Cyprus No Mans Area","170":"Siachen Glacier","171":"Baykonur Cosmodrome","172":"Akrotiri Sovereign Base Area","173":"Southern Patagonian Ice Field","174":"Bir Tawil","175":"Antarctica","176":"Australia","177":"Greenland","178":"Fiji","179":"New Zealand","180":"New Caledonia","181":"Madagascar","182":"Philippines","183":"Sri Lanka","184":"Cura\u00e7ao","185":"Aruba","186":"The Bahamas","187":"Turks and Caicos Islands","188":"Taiwan","189":"Japan","190":"Saint Pierre and Miquelon","191":"Iceland","192":"Pitcairn Islands","193":"French Polynesia","194":"French Southern and Antarctic Lands","195":"Seychelles","196":"Kiribati","197":"Marshall Islands","198":"Trinidad and Tobago","199":"Grenada","200":"Saint Vincent and the Grenadines","201":"Barbados","202":"Saint Lucia","203":"Dominica","204":"United States Minor Outlying Islands","205":"Montserrat","206":"Antigua and Barbuda","207":"Saint Kitts and Nevis","208":"United States Virgin Islands","209":"Saint Barthelemy","210":"Puerto Rico","211":"Anguilla","212":"British Virgin Islands","213":"Jamaica","214":"Caym ...

# %%
import json
world_dict = json.loads(world_data)

# %%
world_df = pd.DataFrame.from_dict(world_dict, orient='columns')
world_df.loc[len(world_df)] = ['Alaska', 'Americas']

# %%
world_df.columns = ['place_country', 'region']

# %%
world_df
# Out:
#                     place_country    region
# 0                       Indonesia      Asia
# 1                        Malaysia      Asia
# 2                           Chile  Americas
# 3                         Bolivia  Americas
# 4                            Peru  Americas
# ..                            ...       ...
# 254   Ashmore and Cartier Islands   Oceania
# 255  Bajo Nuevo Bank (Petrel Is.)  Americas
# 256               Serranilla Bank  Americas
# 257              Scarborough Reef      Asia
# 258                        Alaska  Americas
#
# [259 rows x 2 columns]

# %%
world_df.to_csv('world_data.csv', index='False')

# %% [markdown]
# Generated world_df dataframe that contains list of countries and region. Let's search for countries in the place column of gdf_with_country

# %%
world_df['country_lower'] = world_df['place_country'].str.lower()

# %%
def get_country_from_place(place, country_list):
    place = str(place).lower()
    for country in country_list:
        pattern = r"\b" + re.escape(country.lower()) + r"\b"
        if re.search(pattern, place):
            return country
    return None

# %% [markdown]
# Let us copy a dataframe containing null values while keeping the index

# %%
with_null_df = gdf_with_country[gdf_with_country['country'].isnull()].copy()

# %%
with_null_df
# Out:
#                                             place           time  magnitude  \
# 5                       south of the Fiji Islands  -631286334600        NaN
# 7                   91 km NNE of Lasem, Indonesia  -631331600890        NaN
# 8                         Kermadec Islands region  -631351025130        NaN
# 14                      33 km SSE of Adak, Alaska  -631448307640        NaN
# 15             east of the South Sandwich Islands  -631460084000        NaN
# ...                                           ...            ...        ...
# 9990  139 km NNW of Finschhafen, Papua New Guinea -1059060996230        NaN
# 9992            144 km WNW of Pariaman, Indonesia -1059117808160       6.03
# 9993                                Greenland Sea -1059333702770       5.68
# 9994                                Norwegian Sea -1059336071260       5.44
# 9997                  northern Mid-Atlantic Ridge -1059377901680       5.65
#
#          lat     long  depth alert  tsunami  tz        type  \
# 5    -26.927 -176.566   15.0   NaN        0 NaN  earthquake
# 7     -5.923  111.759  605.0   NaN        0 NaN  earthquake
# 8    -27.889 -177.108  135.0   NaN        0 NaN  earthquake
# 14    51.584 -176.509   35.0   NaN        0 NaN  earthquake
# 15   -59.169  -20.328   15.0   NaN        0 NaN  earthquake
# ...      ...      ...    ...   ...      ...  ..         ...
# 9990  -5.443  147.253  150.0   NaN        0 NaN  earthquake
# 9992  -0.172   98.898   35.0   NaN        0 NaN  earthquake
# 9993  73.128    6.098   15.0   NaN        0 NaN  earthquake
# 9994  72.678    1.764   15.0   NaN        0 NaN  earthquake
# 9997  26.923  -43.335   15.0   NaN        0 NaN  earthquake
#
#                       geometry  index_right country region
# 5     POINT (-176.566 -26.927)          NaN     NaN    NaN
# 7       POINT (111.759 -5.923)          NaN     NaN    NaN
# 8     POINT (-177.108 -27.889)          NaN     NaN    NaN
# 14     POINT (-176.509 51.584)          NaN     NaN    NaN
# 15     POINT (-20.328 -59.169)          NaN     NaN    NaN
# ...                        ...          ...     ...    ...
# 9990    POINT (147.253 -5.443)          NaN     NaN    NaN
# 9992     POINT (98.898 -0.172)          NaN     NaN    NaN
# 9993      POINT (6.098 73.128)          NaN     NaN    NaN
# 9994      POINT (1.764 72.678)          NaN     NaN    NaN
# 9997    POINT (-43.335 26.923)          NaN     NaN    NaN
#
# [3822 rows x 14 columns]

# %%
with_null_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 3822 entries, 5 to 9997
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   place        3822 non-null   object
#  1   time         3822 non-null   int64
#  2   magnitude    2321 non-null   float64
#  3   lat          3822 non-null   float64
#  4   long         3822 non-null   float64
#  5   depth        3781 non-null   float64
#  6   alert        0 non-null      object
#  7   tsunami      3822 non-null   int64
#  8   tz           0 non-null      float64
#  9   type         3822 non-null   object
#  10  geometry     3822 non-null   geometry
#  11  index_right  0 non-null      float64
#  12  country      0 non-null      object
#  13  region       0 non-null      object
# dtypes: float64(6), geometry(1), int64(2), object(5)
# memory usage: 447.9+ KB

# %%
country_list = world_df['country_lower'].tolist()
with_null_df['guess_country'] = with_null_df['place'].apply(lambda x: get_country_from_place(x, country_list))

with_null_df = with_null_df.reset_index().merge(world_df, how='left', left_on='guess_country', right_on='country_lower').set_index('index')

# %%
with_null_df
# Out:
#                                              place           time  magnitude  \
# index
# 5                        south of the Fiji Islands  -631286334600        NaN
# 7                    91 km NNE of Lasem, Indonesia  -631331600890        NaN
# 8                          Kermadec Islands region  -631351025130        NaN
# 14                       33 km SSE of Adak, Alaska  -631448307640        NaN
# 15              east of the South Sandwich Islands  -631460084000        NaN
# ...                                            ...            ...        ...
# 9990   139 km NNW of Finschhafen, Papua New Guinea -1059060996230        NaN
# 9992             144 km WNW of Pariaman, Indonesia -1059117808160       6.03
# 9993                                 Greenland Sea -1059333702770       5.68
# 9994                                 Norwegian Sea -1059336071260       5.44
# 9997                   northern Mid-Atlantic Ridge -1059377901680       5.65
#
#           lat     long  depth alert  tsunami  tz        type  \
# index
# 5     -26.927 -176.566   15.0   NaN        0 NaN  earthquake
# 7      -5.923  111.759  605.0   NaN        0 NaN  earthquake
# 8     -27.889 -177.108  135.0   NaN        0 NaN  earthquake
# 14     51.584 -176.509   35.0   NaN        0 NaN  earthquake
# 15    -59.169  -20.328   15.0   NaN        0 NaN  earthquake
# ...       ...      ...    ...   ...      ...  ..         ...
# 9990   -5.443  147.253  150.0   NaN        0 NaN  earthquake
# 9992   -0.172   98.898   35.0   NaN        0 NaN  earthquake
# 9993   73.128    6.098   15.0   NaN        0 NaN  earthquake
# 9994   72.678    1.764   15.0   NaN        0 NaN  earthquake
# 9997   26.923  -43.335   15.0   NaN        0 NaN  earthquake
#
#                        geometry  index_right country region_x guess_country  \
# index
# 5      POINT (-176.566 -26.927)          NaN     NaN      NaN          fiji
# 7        POINT (111.759 -5.923)          NaN     NaN      NaN     indonesia
# 8      POINT (-177.108 -27.889)          NaN     NaN      NaN          None
# 14      POINT (-176.509 51.584)          NaN     NaN      NaN        alaska
# 15      POINT (-20.328 -59.169)          NaN     NaN      NaN          None
# ...                         ...          ...     ...      ...           ...
# 9990     POINT (147.253 -5.443)          NaN     NaN      NaN        guinea
# 9992      POINT (98.898 -0.172)          NaN     NaN      NaN     indonesia
# 9993       POINT (6.098 73.128)          NaN     NaN      NaN     greenland
# 9994       POINT (1.764 72.678)          NaN     NaN      NaN          None
# 9997     POINT (-43.335 26.923)          NaN     NaN      NaN          None
#
#       place_country  region_y country_lower
# index
# 5              Fiji   Oceania          fiji
# 7         Indonesia      Asia     indonesia
# 8               NaN       NaN           NaN
# 14           Alaska  Americas        alaska
# 15              NaN       NaN           NaN
# ...             ...       ...           ...
# 9990         Guinea    Africa        guinea
# 9992      Indonesia      Asia     indonesia
# 9993      Greenland  Americas     greenland
# 9994            NaN       NaN           NaN
# 9997            NaN       NaN           NaN
#
# [3822 rows x 18 columns]

# %%
with_null_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 3822 entries, 5 to 9997
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   place          3822 non-null   object
#  1   time           3822 non-null   int64
#  2   magnitude      2321 non-null   float64
#  3   lat            3822 non-null   float64
#  4   long           3822 non-null   float64
#  5   depth          3781 non-null   float64
#  6   alert          0 non-null      object
#  7   tsunami        3822 non-null   int64
#  8   tz             0 non-null      float64
#  9   type           3822 non-null   object
#  10  geometry       3822 non-null   geometry
#  11  index_right    0 non-null      float64
#  12  country        0 non-null      object
#  13  region_x       0 non-null      object
#  14  guess_country  2571 non-null   object
#  15  place_country  2571 non-null   object
#  16  region_y       2571 non-null   object
#  17  country_lower  2571 non-null   object
# dtypes: float64(6), geometry(1), int64(2), object(9)
# memory usage: 567.3+ KB

# %%
with_null_df.to_csv('with_null_df.csv')

# %% [markdown]
# Fill the generated dataframe into the gdf_with_country dataframe

# %%
gdf_with_country['country'] = gdf_with_country['country'].fillna(
    with_null_df['place_country'])

gdf_with_country['region'] = gdf_with_country['region'].fillna(
    with_null_df['region_y'])

# %%
gdf_with_country = gdf_with_country.drop(columns=['geometry', 'index_right'])

# %%
gdf_with_country
# Out:
#                                  place           time  magnitude        lat  \
# 0           8km SSW of Lytle Creek, CA  -631157391770       2.58  34.191167
# 1       24km WNW of Searles Valley, CA  -631215832260       2.01  35.859333
# 2        28km N of El Sauzal, B.C., MX  -631241139690       3.30  32.143333
# 3               1km SSW of Artesia, CA  -631251141040       1.83  33.856167
# 4     16km SE of Primo Tapia, B.C., MX  -631284369930       3.02  32.113000
# ...                                ...            ...        ...        ...
# 9995      4km SE of Marina del Rey, CA -1059339147180       1.89  33.953333
# 9996          12km SE of Idyllwild, CA -1059352614360       2.28  33.657167
# 9997       northern Mid-Atlantic Ridge -1059377901680       5.65  26.923000
# 9998           14km WNW of Castaic, CA -1059395737860       2.40  34.543000
# 9999            16km NW of Castaic, CA -1059396414560       2.31  34.588000
#
#             long  depth alert  tsunami  tz        type  \
# 0    -117.522000   4.49   NaN        0 NaN  earthquake
# 1    -117.650667   0.00   NaN        0 NaN  earthquake
# 2    -116.628833   6.00   NaN        0 NaN  earthquake
# 3    -118.089333   0.25   NaN        0 NaN  earthquake
# 4    -116.806333   6.00   NaN        0 NaN  earthquake
# ...          ...    ...   ...      ...  ..         ...
# 9995 -118.426667   6.00   NaN        0 NaN  earthquake
# 9996 -116.644167   6.00   NaN        0 NaN  earthquake
# 9997  -43.335000  15.00   NaN        0 NaN  earthquake
# 9998 -118.757167   6.00   NaN        0 NaN  earthquake
# 9999 -118.749667   6.00   NaN        0 NaN  earthquake
#
#                        country    region
# 0     United States of America  Americas
# 1     United States of America  Americas
# 2                       Mexico  Americas
# 3     United States of America  Americas
# 4                       Mexico  Americas
# ...                        ...       ...
# 9995  United States of America  Americas
# 9996  United States of America  Americas
# 9997                       NaN       NaN
# 9998  United States of America  Americas
# 9999  United States of America  Americas
#
# [10000 rows x 12 columns]

# %%
gdf_with_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   place      10000 non-null  object
#  1   time       10000 non-null  int64
#  2   magnitude  7635 non-null   float64
#  3   lat        10000 non-null  float64
#  4   long       10000 non-null  float64
#  5   depth      9837 non-null   float64
#  6   alert      0 non-null      object
#  7   tsunami    10000 non-null  int64
#  8   tz         0 non-null      float64
#  9   type       10000 non-null  object
#  10  country    8749 non-null   object
#  11  region     8749 non-null   object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1015.6+ KB

# %%
gdf_with_country.to_csv('earthquake-data-wth-countries.csv', index=False)

# %% [markdown]
# As we can see, the non-null values for country and region is increased from 6178 to 8749
